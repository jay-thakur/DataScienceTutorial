# %% [markdown]
# <a href="https://colab.research.google.com/github/jay-thakur/DataScienceTutorial/blob/main/Tensorflow/1_HelloTensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Now, Let's write **Hello World** in tensorflow.

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.6.0

# %% [markdown]
# we have tensorflow installed and verified versions.

# %% [markdown]
# we can use `tf.print()` method to print the text.

# %%
# print just the text message
tf.print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# mmmmmm....... How about **Hello Tensorflow** ?

# %%
tf.print("Hello, Tensorflow!")
# Out:
# Hello, Tensorflow!

# %% [markdown]
# # How can i use python `print()` to print the text?

# %%
text = tf.constant("Hello, Tensorflow!")
print(text)
# Out:
# tf.Tensor(b'Hello, Tensorflow!', shape=(), dtype=string)

# %% [markdown]
# it prints a **Tensor** object which contains the **Hello, World!** text.
#
# **b'** represents byte literal.

# %% [markdown]
# did you notice, we created a Tensor object using `tf.constant`. what is this ?

# %% [markdown]
# # Types of Tensors
#
# * Constant
# * Variable

# %% [markdown]
# Now, Let's consider this equation -
#
#
# $$f(x,y)=x^2y+y+2$$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here, we have -
# * Constant
# * Variable
# * Operations
#
# Let's understand this one by one in upcoming notebooks.

# %% [markdown]
# # References
#
# https://www.easy-tensorflow.com/tf-tutorials/basics/graph-and-session
#
# https://github.com/farhadkamangar/CSE5368
#
# https://cognitiveclass.ai/courses/course-v1:BigDataUniversity+ML0120EN+v2
